# %%
import csv
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

f = open("주민등록인구(연령별).csv")
data = csv.reader(f)
data2=[]

for row in range(3):
    next(data)

for row in data:
    for i in range(88):
        if(row[i+3] == '-'):
            row[i+3] = 0
        else:
            row[i+3] = int(row[i+3].replace(",",""))
    data2.append(row)

age_avg = []
state = []

for row in data2:
    if (row[2] == '계'):
        sum=0
        for i in range(21):
            sum += row[4 + i] * (5 * i + 2) / row[3]
            sum += row[26 + i] * (5 * i + 2)/ row[25]
            sum += row[48 + i] * (5 * i + 2)/ row[47]
            sum += row[70 + i] * (5 * i + 2)/ row[69]
        age_avg.append(sum/4)
        state.append(row[1])
        
plt.figure(figsize=(20,7))
matplotlib.rcParams['font.family'] ='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] =False
plt.bar(state[1:], age_avg[1:], label="평균 나이", color ="C10")
plt.legend(loc="upper left")
plt.xlabel("자치구")
plt.ylabel("평균 나이")
plt.ylim(40,45)
plt.title('자치구별 평균 나이')
plt.show;

# %%
import csv
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

f = open("주민등록인구(연령별).csv")
data = csv.reader(f)
header=[]
header2=[]
data2=[]
age0_4 = []
state = []

for i in range(3):
    header.append(next(data))
for row in data:
    for i in range(88):
        if(row[i+3] == '-'):
            row[i+3] = 0
        else:
            row[i+3] = int(row[i+3].replace(",",""))
    data2.append(row)
for row in data2:
    if (row[2] == '계'):
        sum=0
        for i in range(4):
            sum +=row[4+i*22]
        age0_4.append(sum)
        state.append(row[1])

plt.figure(figsize=(20,7))
matplotlib.rcParams['font.family'] ='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] =False
plt.bar(state[1:], age0_4[1:], label="0~4세", color ="C10")
plt.legend(loc="upper left")
plt.xlabel("자치구")
plt.ylabel("인구수")
plt.title('자치구별 지난 4년간의 신생아 수')
plt.show;

# %%
import csv
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

f = open("주민등록인구(연령별).csv")
data = csv.reader(f)
header=[]
header2=[]
data2=[]
age4_8 = []
state = []

for i in range(3):
    header.append(next(data))
for row in data:
    for i in range(88):
        if(row[i+3] == '-'):
            row[i+3] = 0
        else:
            row[i+3] = int(row[i+3].replace(",",""))
    data2.append(row)
    
for row in data2:
    if (row[2] == '계'):
        sum=0
        for i in range(4):
            sum +=row[5+i*22]
        age4_8.append(sum)
        state.append(row[1])

plt.figure(figsize=(20,7))
matplotlib.rcParams['font.family'] ='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] =False
plt.bar(state[1:], age4_8[1:], label="4~8세", color ="C10")
plt.legend(loc="upper right")
plt.xlabel("자치구")
plt.ylabel("인구수")
plt.title('초등학교 및 유치원 취학 연령 인구수')
plt.show;

# %%
fig, ax = plt.subplots(figsize=(20,7))
bar_width = 0.25
index = np.arange(25)

matplotlib.rcParams['font.family'] ='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] =False

b1 = plt.bar(index, age0_4[1:], bar_width, label="0~4세")
b2 = plt.bar(index + bar_width, age4_8[1:], bar_width, label="4~8세")

plt.xticks(np.arange(bar_width, 25 + bar_width, 1), state[1:])

plt.xlabel("자치구", size = 13)
plt.ylabel("인구수", size = 13)
plt.legend(loc='upper left')
plt.show;

# %%
fig, ax = plt.subplots(figsize=(20,7))
bar_width = 0.35
index = np.arange(25)

matplotlib.rcParams['font.family'] ='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] =False

b1 = plt.bar(index, age0_4[1:], bar_width, label="0~4세")
b2 = plt.bar(index + bar_width, age4_8[1:], bar_width, label="4~8세")

plt.xticks(np.arange(bar_width, 25 + bar_width, 1), state[1:])

plt.xlabel("자치구", size = 13)
plt.ylabel("인구수", size = 13)

plt.legend(loc = 'upper left')
ax2 = ax.twinx()

ax2.plot(index, age_avg[1:], ls = ":", color = 'black' ,
         marker = 'o',label = "평균 나이")
ax2.legend(loc = 'upper right')

plt.show;

# %%
import csv
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd


f = open("서울시 범죄 발생현황_2019.csv")
data = csv.reader(f)

header = [
"소계",
"살인",
"강도",
"강간강제추행",
"절도",
"폭력"
]
state = []
prime_rate = [[] for i in range(6)]
prime = [[] for i in range(12)]
    
    
for row in range(5):
    header.append(next(data))
    
for row in data:
    state.append(row[1])
    for i in range(6):
        row[2*i+2] = int(row[2*i+2].replace(",", ""))
        row[2*i+3] = int(row[2*i+3].replace(",", ""))
        rate = row[2*i+3]/row[2*i+2]
        prime_rate[i].append(rate)
    for i in range(12):
        prime[i].append(row[i+2])

# %%
fig, ax = plt.subplots(figsize=(17,7))
bar_width = 0.15
index = np.arange(25)


matplotlib.rcParams['font.family'] ='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] =False

b1 = plt.bar(index + 2* bar_width , prime_rate[0], 5*bar_width, color = 'red', label="소계")
b2 = plt.bar(index ,  prime_rate[1], bar_width,color = 'orange', label="살인")
b3 = plt.bar(index +  bar_width,  prime_rate[2], bar_width,color='yellow', label="강도")
b4 = plt.bar(index + 2 * bar_width,  prime_rate[3], bar_width, color = 'pink',label="강간*강제추행")
b5 = plt.bar(index + 3 * bar_width,  prime_rate[4], bar_width,color = 'wheat', label="절도")
b5 = plt.bar(index + 4 *  bar_width,  prime_rate[5], bar_width, color = 'lightblue',label="폭력")

plt.xticks(np.arange(bar_width, 25 + bar_width, 1), state)

plt.xlabel("자치구", size = 13)
plt.ylabel("검거/발생 (검거비율)", size = 13)

plt.legend(loc = 'upper left')
ax2 = ax.twinx()

ax2.plot(index + 2 * bar_width , age0_4[1:], ls = ":", color = 'black' ,
         marker = 'o',markersize = 10,label = "신생아 수")
ax2.legend(loc = 'upper right')

plt.title("서울 5대 범죄의 사건 해결비율와 신생아 수의 연관성")
plt.savefig("서울 5대 범죄와 신생아 수의 연관성.jpg")
plt.show;

# %%
fig, ax = plt.subplots(figsize=(17,7))
bar_width = 0.15
index = np.arange(25)

index = np.arange(25)
plt.bar(index, prime[0], label = "모든 범죄 수")
plt.legend(loc = 'upper left')
plt.ylabel("인원수")
ax2 = ax.twinx()
ax2.plot(index , age0_4[1:], ls = ":", color = 'black' ,
         marker = 'o',markersize = 10,label = "신생아 수")
ax2.legend(loc = 'upper right')
plt.xticks(np.arange(bar_width, 25 + bar_width, 1), state)
plt.title("2019년 자치구별 일어난 5대 범죄 수")
plt.show;

# %%
import csv
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

f = open("주민등록인구(연령별).csv")
data = csv.reader(f)
data2=[]
header=[]

for row in range(6):
    header.append(next(data))

for row in data:
    for i in range(88):
        if(row[i+3] == '-'):
            row[i+3] = 0
        else:
            row[i+3] = int(row[i+3].replace(",",""))
    data2.append(row)

sivil = []
state = []

for row in data2:
    sum = 0
    if (row[2] == '계'):
        for i in range(4):
            sum+=row[i+3]
        sivil.append(sum)
        state.append(row[1])

df = pd.DataFrame(sivil)
df = df.transpose()
df.columns = state
df
# Out:
#       종로구      중구     용산구     성동구     광진구    동대문구     중랑구     성북구     강북구  \
# 0  177097  147302  269073  347538  407013  397637  446337  499480  350248
#
#       도봉구  ...     강서구     구로구     금천구    영등포구     동작구     관악구     서초구  \
# 0  374292  ...  671287  486965  277396  444770  453654  561795  497018
#
#       강남구     송파구     강동구
# 0  614026  769918  478592
#
# [1 rows x 25 columns]

# %%
prime2 = []
for i in range(25):
    prime2.append(prime[0][i]/sivil[i])

# %%
fig, ax = plt.subplots(figsize=(17,7))
bar_width = 0.15
index = np.arange(25)

index = np.arange(25)
plt.bar(index, prime2, label = "발생 건수/인구수")
plt.legend(loc = 'upper left')
plt.ylabel("발생건수/인구수")
ax2 = ax.twinx()
ax2.plot(index , age0_4[1:], ls = ":", color = 'black' ,
         marker = 'o',markersize = 10,label = "신생아 수")
ax2.legend(loc = 'upper right')
plt.xticks(np.arange(bar_width, 25 + bar_width, 1), state)
plt.title("2019년 자치구별 일어난 5대 범죄의 인구수대비 "
          + "발생건수와 신생아수의 상관관계")
plt.show;

# %%
import csv
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

f = open("서울시+자치구별+초등학교.csv")
data = csv.reader(f)
elementary = []
header=[]

for row in range(5):
    header.append(next(data))

for row in data:
    elementary.append(int(row[44]))
df = pd.DataFrame(elementary)
df = df.transpose()
df.columns = state
df
# Out:
#    종로구  중구  용산구  성동구  광진구  동대문구  중랑구  성북구  강북구  도봉구  ...  강서구  구로구  금천구  영등포구  \
# 0   13  12   15   21   22    21   23   29   14   23  ...   36   26   18    23
#
#    동작구  관악구  서초구  강남구  송파구  강동구
# 0   21   22   24   33   40   27
#
# [1 rows x 25 columns]

# %%
fig, ax = plt.subplots(figsize=(17,7))
bar_width = 0.15
index = np.arange(25)

index = np.arange(25)
plt.bar(index, elementary,color ='lightgreen', label = "초등학교 수")
plt.legend(loc = 'upper left')
plt.ylabel("초등학교수")
ax2 = ax.twinx()
ax2.plot(index , age0_4[1:], ls = ":", color = 'black' ,
         marker = 'o',markersize = 10,label = "신생아 수")
ax2.legend(loc = 'upper right')
plt.xticks(np.arange(bar_width, 25 + bar_width, 1), state)
plt.title("2019년 초등학교 와 신생아수의 상관관계 ")
plt.show;

# %%
import pandas as pd
import numpy as np
import folium
import json

geo_str = json.load(open("skorea_municipalities_geo_simple.json",
                         encoding='utf-8'))
seoul_map = folium.Map(location=[37.5502, 126.982], zoom_start = 10.5)
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
df = pd.DataFrame(state)
df['인원수'] = age0_4
df = df.drop(0)
df.columns = ['자치구', '인원수']
map_group = df.groupby('자치구')['인원수'].sum()

# %%
map_group.fillna(
    method = 'pad',
    inplace = True
)

# %%
seoul_map = folium.Map(location=[37.5502, 126.982], zoom_start = 10.5)
folium.Choropleth(
    geo_data = geo_str,
    data = map_group,
    columns = ['인원수', '자치구'],
    fill_color = 'YlOrRd',
    key_on = 'feature.properties.name'
).add_to(seoul_map)

seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import csv
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

f = open("자치구별+1인당+지역내총생산+및+수준지수(2019).csv")
data = csv.reader(f)

header = []
GDP = []
state = []

for i in range(3):
    header.append(next(data))
    
for row in data:
    GDP.append(int(row[5].replace(",","")))
    state.append(row[1])
df = pd.DataFrame(GDP)
df = df.transpose()
df.columns = state
# Out:
#       종로구      중구    용산구    성동구    광진구   동대문구    중랑구    성북구    강북구    도봉구  \
# 0  218704  417483  56571  40100  18211  21033  12174  13894  10743  10438
#
#    ...    강서구    구로구    금천구   영등포구    동작구    관악구    서초구     강남구    송파구    강동구
# 0  ...  30176  32692  70750  91575  16197  11663  87695  141362  46033  22807
#
# [1 rows x 25 columns]

# %%
fig, ax = plt.subplots(figsize=(17,7))
bar_width = 0.15
index = np.arange(25)

plt.bar(index, GDP,color ='lightgreen', label = "1인당 지역내총생산 (천원)")
plt.legend(loc = 'upper left')
plt.ylabel("1인당 지역내총생산 (천원)")
ax2 = ax.twinx()
ax2.plot(index , age0_4[1:], ls = ":", color = 'black' ,
         marker = 'o',markersize = 10,label = "신생아 수")
ax2.legend(loc = 'upper right')
plt.xticks(np.arange(bar_width, 25 + bar_width, 1), state)
plt.title("1인당 지역내 총생산량과 신생아수의 상관관계 ")
plt.show;

# %%
fig, ax = plt.subplots(figsize=(17,7))
bar_width = 0.15
index = np.arange(23)

plt.bar(index, GDP[2:],color ='lightgreen', label = "1인당 지역내총생산 (천원)")
plt.legend(loc = 'upper left')
plt.ylabel("1인당 지역내총생산 (천원)")
ax2 = ax.twinx()
ax2.plot(index , age0_4[3:], ls = ":", color = 'black' ,
         marker = 'o',markersize = 10,label = "신생아 수")
ax2.legend(loc = 'upper right')
plt.xticks(np.arange(bar_width, 23 + bar_width, 1), state[2:])
plt.title("1인당 지역내 총생산량과 신생아수의 상관관계 ")
plt.show;

# %%
import csv
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

f = open("상급학교_진학률_2019.csv")
data = csv.reader(f)

header = []
pre_edu = []
state = []

for i in range(3):
    header.append(next(data))
    
for row in data:
    if row[3]=='소계':
        pre_edu.append(float(row[6].replace(",","")))
        state.append(row[1])
        
df = pd.DataFrame(pre_edu)
df[''] = state
df.columns = ['진학률', '자치구']

df.sort_values(by='진학률').head()
# Out:
#      진학률  자치구
# 1   43.7   중구
# 22  44.8  강남구
# 3   50.9  성동구
# 19  51.5  동작구
# 21  52.0  서초구

# %%
fig, ax = plt.subplots(figsize=(17,7))
bar_width = 0.15
index = np.arange(25)

plt.bar(index, pre_edu,color ='lightgreen', label = "상급학교 진학률")
plt.ylim(40,70)
plt.legend(loc = 'upper left')
plt.ylabel("상급학교 진학률 (%)")
ax2 = ax.twinx()
ax2.plot(index , age0_4[1:], ls = ":", color = 'black' ,
         marker = 'o',markersize = 10,label = "신생아 수")
ax2.legend(loc = 'upper right')
plt.xticks(np.arange(bar_width, 25 + bar_width, 1), state)
plt.title("상급학교 진학률과 신생아수의 상관관계 ")
plt.show;
